# %% [markdown]
# # Application of Computational Biology and Artificial Intelligence in Drug Design

# %%
"""
Disease: COVID-19

COVID-19 is caused by the SARS-CoV-2 virus.
The virus relies on specific proteins for replication and survival.
Targeting these proteins can inhibit viral growth.
"""

# %%
"""
Target Protein: SARS-CoV-2 Main Protease (Mpro)

• Essential for viral replication
• Highly conserved
• Ideal drug target
• PDB ID: 6LU7
"""

# %%
"""
Traditional drug discovery is time-consuming and expensive.
Computational biology helps analyze protein structures.
AI models help predict drug activity efficiently.
This project integrates both approaches.
"""
